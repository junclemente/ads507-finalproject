# %% [markdown]
# <a href="https://colab.research.google.com/github/junclemente/ads507-finalproject/blob/main/ADS_507_EDA_Source_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# ## Import Data & Libraries

# %%
#library imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#get URLS
traffic_url = 'https://raw.githubusercontent.com/junclemente/ads507-finalproject/main/datasets/traffic_alerts.csv'
weather_url = 'https://raw.githubusercontent.com/junclemente/ads507-finalproject/main/datasets/weather_alerts.csv'
travel_url = 'https://raw.githubusercontent.com/junclemente/ads507-finalproject/main/datasets/travel_times.csv'

# Read the CSV file
traffic_df = pd.read_csv(traffic_url)
weather_df = pd.read_csv(weather_url)
travel_df = pd.read_csv(travel_url)

# %% [markdown]
# ## Create functions

# %%
#create categorical data quality report function
# Calculate mode and frequency for each categorical feature
def cat_dqr(df, categorical_features):  # define function to calculate categorical features
    modes = []
    mode_freqs = []
    second_modes = []
    second_mode_freqs = []
    mode_percentages = []
    second_mode_percentages = []

    for feature in categorical_features:
        count = df[feature].count()
        value_counts = df[feature].value_counts()

        # Mode and its frequency
        mode = value_counts.index[0] if not value_counts.empty else None
        mode_freq = value_counts.iloc[0] if not value_counts.empty else 0
        mode_percentage = (mode_freq / count) * 100 if count > 0 else 0

        # Second mode and its frequency
        if len(value_counts) > 1:
            second_mode = value_counts.index[1]
            second_mode_freq = value_counts.iloc[1]
            second_mode_percentage = (second_mode_freq / count) * 100 if count > 0 else 0
        else:
            second_mode = None
            second_mode_freq = 0
            second_mode_percentage = 0

        # Append results
        modes.append(mode)
        mode_freqs.append(mode_freq)
        mode_percentages.append(mode_percentage)
        second_modes.append(second_mode)
        second_mode_freqs.append(second_mode_freq)
        second_mode_percentages.append(second_mode_percentage)

    # Build the data quality report
    cat_quality = pd.DataFrame({
        'Feature': categorical_features,
        'Count': df[categorical_features].count().values,
        'Missing Values': df[categorical_features].isnull().sum().values,
        'Cardinality': df[categorical_features].nunique().values,
        'Mode': modes,
        'Mode Frequency': mode_freqs,
        'Mode %': mode_percentages,
        '2nd Mode': second_modes,
        '2nd Mode Frequency': second_mode_freqs,
        '2nd Mode %': second_mode_percentages,
    })

    return cat_quality

# %%
#create continuous data quality function
def cont_dqr(df, exclude_columns=None):
    # Select continuous features (int64, float64)
    continuous_features = df.select_dtypes(include=['float64', 'int64']).columns.tolist()

    # Exclude specified columns
    if exclude_columns:
        continuous_features = [col for col in continuous_features if col not in exclude_columns]

    # Build the data quality report for continuous features
    cont_quality = pd.DataFrame({
        'Feature': continuous_features,
        'Count': df[continuous_features].count().values,
        'Missing Values': df[continuous_features].isnull().sum().values,
        'Cardinality': df[continuous_features].nunique().values,
        'Min': df[continuous_features].min().values,
        '1st Quartile': df[continuous_features].quantile(0.25).values,
        'Mean': df[continuous_features].mean().values,
        'Median': df[continuous_features].median().values,
        '3rd Quartile': df[continuous_features].quantile(0.75).values,
        'Max': df[continuous_features].max().values,
        'Standard Deviation': df[continuous_features].std().values,
    })

    return cont_quality

# %% [markdown]
# # Traffic Data

# %% [markdown]
# ## Traffic Data Review

# %%
traffic_df.head()
# Out:
#    AlertID        County                                 EndRoadwayLocation  \
# 0   624112         Grant  {"Description": null, "Direction": "B", "Latit...
# 1   632850           NaN  {"Description": null, "Direction": "B", "Latit...
# 2   632245           NaN  {"Description": null, "Direction": "B", "Latit...
# 3   626169  Pend Oreille  {"Description": null, "Direction": "B", "Latit...
# 4   632835           NaN  {"Description": null, "Direction": "B", "Latit...
#
#                       EndTime EventCategory EventStatus  ExtendedDescription  \
# 0                         NaN     Rest Area        Open                  NaN
# 1  /Date(1738328400000-0800)/   Maintenance        Open                  NaN
# 2  /Date(1738371600000-0800)/   Maintenance        Open                  NaN
# 3                         NaN   Road Report        Open                  NaN
# 4                         NaN  Construction        Open                  NaN
#
#                                  HeadlineDescription  \
# 0  The blue Lake rest area is closed for the winter.
# 1  Nightly from 9 p.m. until 5 a.m. Sunday, Jan. ...
# 2  Weekdays, from 7 a.m. to 5 p.m., Wednesday, Ja...
# 3  US2 from Spokane to Newport, road condition:  ...
# 4  Eastbound and westbound SR 18 will shift to th...
#
#               LastUpdatedTime Priority         Region  \
# 0  /Date(1731629066113-0800)/      Low  North Central
# 1  /Date(1737765776500-0800)/     High      Northwest
# 2  /Date(1737148405100-0800)/      Low      Northwest
# 3  /Date(1738649920440-0800)/   Medium        Eastern
# 4  /Date(1737761204897-0800)/      Low      Northwest
#
#                                 StartRoadwayLocation  \
# 0  {"Description": null, "Direction": "B", "Latit...
# 1  {"Description": null, "Direction": "B", "Latit...
# 2  {"Description": null, "Direction": "B", "Latit...
# 3  {"Description": null, "Direction": "B", "Latit...
# 4  {"Description": null, "Direction": "B", "Latit...
#
#                     StartTime                   timestamp  ta_id
# 0  /Date(1731628800000-0800)/  2025-02-03 22:21:17.828031      2
# 1  /Date(1737765300000-0800)/  2025-02-03 22:21:17.828031      2
# 2  /Date(1737148080000-0800)/  2025-02-03 22:21:17.828031      2
# 3  /Date(1738642140000-0800)/  2025-02-03 22:21:17.828031      2
# 4  /Date(1738155600000-0800)/  2025-02-03 22:21:17.828031      2

# %%
traffic_df.shape
# Out:
# (203, 15)

# %%
#are there duplicates?
traffic_df.duplicated().sum()
# Out:
# 0

# %%
#get datatypes
traffic_df.dtypes
# Out:
# AlertID                   int64
# County                   object
# EndRoadwayLocation       object
# EndTime                  object
# EventCategory            object
# EventStatus              object
# ExtendedDescription     float64
# HeadlineDescription      object
# LastUpdatedTime          object
# Priority                 object
# Region                   object
# StartRoadwayLocation     object
# StartTime                object
# timestamp                object
# ta_id                     int64
# dtype: object

# %%
traffic_df['AlertID'].nunique()
# Out:
# 203

# %%
traffic_df['ta_id'].nunique()
# Out:
# 1

# %% [markdown]
# There is 203 rows, Alert ID has 203 values. Thus every is unique / candidate for a primary key. ta ID appears to only have one value, everything = '2'.

# %% [markdown]
# ## Data Quality Report - Traffic

# %% [markdown]
# Will do categorical data only as the integer data is not needed.

# %%
traffic_catf = traffic_df.select_dtypes(include=['object', 'category']).columns.tolist()
traffic_quality_report = cat_dqr(traffic_df, traffic_catf)
traffic_quality_report
# Out:
#                  Feature  Count  Missing Values  Cardinality  \
# 0                 County     18             185           11
# 1     EndRoadwayLocation    203               0          131
# 2                EndTime    161              42           90
# 3          EventCategory    203               0           14
# 4            EventStatus    203               0            1
# 5    HeadlineDescription    203               0          201
# 6        LastUpdatedTime    203               0          203
# 7               Priority    203               0            5
# 8                 Region    203               0            6
# 9   StartRoadwayLocation    203               0          170
# 10             StartTime    203               0          134
# 11             timestamp    203               0            1
#
#                                                  Mode  Mode Frequency  \
# 0                                             Spokane               6
# 1   {"Description": null, "Direction": "N", "Latit...              18
# 2                          /Date(1738328400000-0800)/              20
# 3                                        Construction             139
# 4                                                Open             203
# 5   The Iron Goat rest area is closed for the winter.               2
# 6                          /Date(1731629066113-0800)/               1
# 7                                              Medium             108
# 8                                           Northwest             147
# 9   {"Description": null, "Direction": "S", "Latit...               3
# 10                         /Date(1737964800000-0800)/              28
# 11                         2025-02-03 22:21:17.828031             203
#
#         Mode %                                           2nd Mode  \
# 0    33.333333                                            Whitman
# 1     8.866995  {"Description": null, "Direction": "S", "Latit...
# 2    12.422360                         /Date(1738933200000-0800)/
# 3    68.472906                                        Maintenance
# 4   100.000000                                               None
# 5     0.985222  From 8 a.m. Monday, Feb. 3 until noon Friday, ...
# 6     0.492611                         /Date(1737761028007-0800)/
# 7    53.201970                                                Low
# 8    72.413793                                            Olympic
# 9     1.477833  {"Description": null, "Direction": "N", "Latit...
# 10   13.793103                         /Date(1738569600000-0800)/
# 11  100.000000                                               None
#
#     2nd Mode Frequency  2nd Mode %
# 0                    3   16.666667
# 1                    9    4.433498
# 2                   10    6.211180
# 3                   26   12.807882
# 4                    0    0.000000
# 5                    2    0.985222
# 6                    1    0.492611
# 7                   70   34.482759
# 8                   20    9.852217
# 9                    3    1.477833
# 10                  28   13.793103
# 11                   0    0.000000

# %% [markdown]
# # Weather Data

# %% [markdown]
# ## Weather Data Review

# %%
weather_df.head()
# Out:
#    BarometricPressure   Latitude   Longitude  PrecipitationInInches  \
# 0               950.0  47.474800 -122.270400                    NaN
# 1               894.7  47.760633 -122.184048                    NaN
# 2               971.6  47.509000 -121.885000                    NaN
# 3               993.5  47.726000 -122.324000                    NaN
# 4                 NaN  46.436000 -117.350000                    NaN
#
#                   ReadingTime  RelativeHumidity  SkyCoverage  StationID  \
# 0  /Date(1738648806000-0800)/              99.0          NaN       1909
# 1  /Date(1738648817000-0800)/             100.0          NaN       1910
# 2  /Date(1738648807000-0800)/              98.0          NaN       1928
# 3  /Date(1738648871000-0800)/              96.0          NaN       1966
# 4  /Date(1738649254000-0800)/              93.0          NaN       1968
#
#                                StationName  TemperatureInFahrenheit  \
# 0        S 144th St on SB I-5 at mp 155.32                    34.52
# 1         NE 195th on SB I-405 at mp 24.58                    32.72
# 2  EB I-90 / SR-18 (Echo Lake) at mp 26.30                    31.28
# 3      NE 130th Street on I-5 at mp 173.75                    33.80
# 4      Alpowa Summit on US 12 at mp 413.36                    30.20
#
#    Visibility  WindDirection WindDirectionCardinal  WindGustSpeedInMPH  \
# 0         1.0          130.0                    SE                 1.0
# 1         1.0            5.0                     N                 0.0
# 2         1.0            NaN                   NaN                 1.0
# 3         1.0            NaN                   NaN                 1.0
# 4        12.0          171.0                     S                 8.0
#
#    WindSpeedInMPH                   timestamp  wa_id
# 0             0.0  2025-02-03 22:21:17.828031      3
# 1             0.0  2025-02-03 22:21:17.828031      3
# 2             0.0  2025-02-03 22:21:17.828031      3
# 3             0.0  2025-02-03 22:21:17.828031      3
# 4             6.0  2025-02-03 22:21:17.828031      3

# %%
#are there duplicates?
weather_df.duplicated().sum()
# Out:
# 0

# %%
#get data types
weather_df.dtypes
# Out:
# BarometricPressure         float64
# Latitude                   float64
# Longitude                  float64
# PrecipitationInInches      float64
# ReadingTime                 object
# RelativeHumidity           float64
# SkyCoverage                float64
# StationID                    int64
# StationName                 object
# TemperatureInFahrenheit    float64
# Visibility                 float64
# WindDirection              float64
# WindDirectionCardinal       object
# WindGustSpeedInMPH         float64
# WindSpeedInMPH             float64
# timestamp                   object
# wa_id                        int64
# dtype: object

# %% [markdown]
# ## Weather Data Quality Report

# %% [markdown]
# ### Weather Continuous Data Quality Report

# %%
exclude_columns = []
weather_cont_quality = cont_dqr(weather_df, exclude_columns)
weather_cont_quality
# Out:
#                     Feature  Count  Missing Values  Cardinality       Min  \
# 0        BarometricPressure     34              69           33   825.500
# 1                  Latitude    103               0          103    45.569
# 2                 Longitude    103               0          103  -124.333
# 3     PrecipitationInInches      0             103            0       NaN
# 4          RelativeHumidity     90              13           34     1.000
# 5               SkyCoverage      0             103            0       NaN
# 6                 StationID    103               0          103  1909.000
# 7   TemperatureInFahrenheit     94               9           61   -36.400
# 8                Visibility     86              17            3     0.000
# 9             WindDirection     68              35           39     0.000
# 10       WindGustSpeedInMPH     94               9           16     0.000
# 11           WindSpeedInMPH     94               9           12     0.000
# 12                    wa_id    103               0            1     3.000
#
#     1st Quartile         Mean       Median  3rd Quartile          Max  \
# 0     946.325000   965.820588   979.300000    996.275000  1099.500000
# 1      46.537730    47.220197    47.240023     47.751200    49.000000
# 2    -122.401108  -120.779463  -120.786000   -119.396143  -117.081125
# 3            NaN          NaN          NaN           NaN          NaN
# 4      77.250000    84.133333    90.500000     97.000000   100.000000
# 5            NaN          NaN          NaN           NaN          NaN
# 6    2097.500000  2975.378641  2955.000000   3271.500000  5927.000000
# 7      27.320000    29.024255    30.740000     33.080000    36.320000
# 8       1.000000     0.965116     1.000000      1.000000    12.000000
# 9      10.000000    82.514706    67.500000    145.500000   230.000000
# 10      1.000000     3.978723     2.000000      6.000000    23.000000
# 11      0.000000     2.265957     1.000000      4.000000    18.000000
# 12      3.000000     3.000000     3.000000      3.000000     3.000000
#
#     Standard Deviation
# 0         5.453081e+01
# 1         8.370237e-01
# 2         1.980481e+00
# 3                  NaN
# 4         1.963041e+01
# 5                  NaN
# 6         1.000412e+03
# 7         8.217564e+00
# 8         1.259764e+00
# 9         7.243000e+01
# 10        4.870315e+00
# 11        3.360669e+00
# 12        4.462608e-16

# %% [markdown]
# wa_id is not helpful as a primary key. We will need to create a new one. SkyCoverage completely null. Have Long/Lat for everything

# %% [markdown]
# ### Weather Categorical Data Quality Report

# %%
weather_catf = weather_df.select_dtypes(include=['object', 'category']).columns.tolist()
weather_quality_report = cat_dqr(weather_df, weather_catf)
weather_quality_report
# Out:
#                  Feature  Count  Missing Values  Cardinality  \
# 0            ReadingTime    103               0          102
# 1            StationName    103               0          103
# 2  WindDirectionCardinal     58              45           11
# 3              timestamp    103               0            1
#
#                                 Mode  Mode Frequency      Mode %  \
# 0         /Date(1738649594000-0800)/               2    1.941748
# 1  S 144th St on SB I-5 at mp 155.32               1    0.970874
# 2                                  N               8   13.793103
# 3         2025-02-03 22:21:17.828031             103  100.000000
#
#                      2nd Mode  2nd Mode Frequency  2nd Mode %
# 0  /Date(1738648806000-0800)/                   1    0.970874
# 1  Parker on I-82 at mp 41.50                   1    0.970874
# 2                         ENE                   7   12.068966
# 3                        None                   0    0.000000

# %% [markdown]
# # Travel

# %% [markdown]
# ## Travel Data Review

# %%
travel_df.head()
# Out:
#    AverageTime  CurrentTime                                    Description  \
# 0           25           25    Everett to Downtown Seattle using HOV lanes
# 1           27           25    Downtown Seattle to Everett using HOV lanes
# 2           27           25                    Downtown Seattle to Everett
# 3            9            9                  Downtown Bellevue to Issaquah
# 4            9            9  Downtown Bellevue to Issaquah using HOV lanes
#
#    Distance                                           EndPoint  \
# 0     26.72  {"Description": "I-5 @ University St in Seattl...
# 1     26.94  {"Description": "I-5 @ 41st St in Everett", "D...
# 2     26.94  {"Description": "I-5 @ 41st St in Everett", "D...
# 3      9.28  {"Description": "I-90 @ Front St in Issaquah",...
# 4      9.28  {"Description": "I-90 @ Front St in Issaquah",...
#
#                     Name                                         StartPoint  \
# 0    Everett-Seattle HOV  {"Description": "I-5 @ 41st St in Everett", "D...
# 1    Seattle-Everett HOV  {"Description": "I-5 @ University St in Seattl...
# 2        Seattle-Everett  {"Description": "I-5 @ University St in Seattl...
# 3      Bellevue-Issaquah  {"Description": "I-405 @ NE 8th St in Bellevue...
# 4  Bellevue-Issaquah HOV  {"Description": "I-405 @ NE 8th St in Bellevue...
#
#                   TimeUpdated  TravelTimeID                   timestamp  tt_id
# 0  /Date(1738650000000-0800)/             2  2025-02-03 22:21:17.828031      1
# 1  /Date(1738650000000-0800)/             3  2025-02-03 22:21:17.828031      1
# 2  /Date(1738650000000-0800)/             4  2025-02-03 22:21:17.828031      1
# 3  /Date(1738650000000-0800)/             5  2025-02-03 22:21:17.828031      1
# 4  /Date(1738650000000-0800)/             6  2025-02-03 22:21:17.828031      1

# %%
#are there duplicate rows?
travel_df.duplicated().sum()
# Out:
# 0

# %%
#get data types
travel_df.dtypes
# Out:
# AverageTime       int64
# CurrentTime       int64
# Description      object
# Distance        float64
# EndPoint         object
# Name             object
# StartPoint       object
# TimeUpdated      object
# TravelTimeID      int64
# timestamp        object
# tt_id             int64
# dtype: object

# %% [markdown]
# ## Travel Data Quality Report

# %% [markdown]
# ### Travel Continuous Data Quality Report

# %%
exclude_columns = []
travel_cont_quality = cont_dqr(travel_df, exclude_columns)
travel_cont_quality
# Out:
#         Feature  Count  Missing Values  Cardinality   Min  1st Quartile  \
# 0   AverageTime    168               0           31  0.00        9.0000
# 1   CurrentTime    168               0           33  0.00        9.0000
# 2      Distance    168               0          122  2.66        9.6125
# 3  TravelTimeID    168               0          168  1.00       45.7500
# 4         tt_id    168               0            1  1.00        1.0000
#
#          Mean   Median  3rd Quartile     Max  Standard Deviation
# 0   14.482143   13.000       19.2500   38.00            7.526379
# 1   15.083333   14.000       20.0000   50.00            8.155977
# 2   15.110179   13.545       18.3325   39.79            7.367362
# 3  192.303571  109.000      344.2500  532.00          160.769957
# 4    1.000000    1.000        1.0000    1.00            0.000000

# %% [markdown]
# ### Categorical Data Quality Report

# %%
travel_catf = travel_df.select_dtypes(include=['object', 'category']).columns.tolist()
travel_quality_report = cat_dqr(travel_df, travel_catf)
travel_quality_report
# Out:
#        Feature  Count  Missing Values  Cardinality  \
# 0  Description    168               0          165
# 1     EndPoint    168               0           89
# 2         Name    168               0          168
# 3   StartPoint    168               0           91
# 4  TimeUpdated    168               0            1
# 5    timestamp    168               0            1
#
#                                                 Mode  Mode Frequency  \
# 0                    Downtown Seattle to Woodinville               2
# 1  {"Description": "I-5 @ University St in Seattl...              13
# 2                                Everett-Seattle HOV               1
# 3  {"Description": "I-5 @ University St in Seattl...              11
# 4                         /Date(1738650000000-0800)/             168
# 5                         2025-02-03 22:21:17.828031             168
#
#        Mode %                                           2nd Mode  \
# 0    1.190476                    Woodinville to Downtown Seattle
# 1    7.738095  {"Description": "I-5 @ University St in Seattl...
# 2    0.595238                King County Line to Federal Way HOV
# 3    6.547619  {"Description": "I-405 @ NE 8th St in Bellevue...
# 4  100.000000                                               None
# 5  100.000000                                               None
#
#    2nd Mode Frequency  2nd Mode %
# 0                   2    1.190476
# 1                  12    7.142857
# 2                   1    0.595238
# 3                  10    5.952381
# 4                   0    0.000000
# 5                   0    0.000000
