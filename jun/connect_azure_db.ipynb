# %%
import pandas as pd
import os
import pymysql
import requests


from dotenv import load_dotenv
from urllib.parse import quote_plus
from sqlalchemy import create_engine, inspect

# %%
from dotenv import load_dotenv

load_dotenv()

db_user = os.getenv("AZURE_USERNAME")
db_pwd = os.getenv("AZURE_PWD")
db_host = os.getenv("AZURE_URL")
db_port = os.getenv("AZURE_PORT")
db_database = os.getenv("AZURE_DB")

# print(db_username)
# print(db_pwd)
# print(db_url)

# %%
# Connect to database
connection_url = (
    f"mysql+pymysql://{db_user}:{quote_plus(db_pwd)}"
    f"@{db_host}:{db_port}/{db_database}?"
    f"ssl_ca=./DigiCertGlobalRootG2.crt.pem"
)

try:
    engine = create_engine(connection_url)
    print("Connection successful!")
except Exception as e:
    print("Connection unsuccessful! The error is: ", e)
# Out:
# Connection successful!

# %%
# inspector = inspect(engine)
query = """ 
    SHOW TABLES
"""

df = pd.read_sql_query(query, engine)
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/miniconda3/envs/ads507/lib/python3.12/site-packages/pymysql/connections.py:669, in Connection.connect(self, sock)
#     668 self._get_server_information()
# --> 669 self._request_authentication()
#     671 # Send "SET NAMES" query on init for:
#     672 # - Ensure charaset (and collation) is set to the server.
#     673 #   - collation_id in handshake packet may be ignored.
#    (...)
#     682 # - https://github.com/wagtail/wagtail/issues/9477
#     683 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#
# File ~/miniconda3/envs/ads507/lib/python3.12/site-packages/pymysql/connections.py:899, in Connection._request_authentication(self)
#     897 self.write_packet(data_init)
# --> 899 self._sock = self.ctx.wrap_socket(self._sock, server_hostname=self.host)
# ...
