# %%
import pandas as pd
import os
import requests


from dotenv import load_dotenv
from sqlalchemy import create_engine, inspect

# %%
from dotenv import load_dotenv

load_dotenv()

db_username = os.getenv("AZURE_USERNAME")
db_pwd = os.getenv("AZURE_PWD")
db_url = os.getenv("AZURE_URL")

# print(db_username)
# print(db_pwd)
# print(db_url)

# %%
# Connect to database
engine = create_engine(f"mysql+pymysql://{db_username}:{db_pwd}@{db_url}/api_fetch_raw")

# %%
# inspector = inspect(engine)
query = "SELECT * FROM api_fetch_raw"
df = pd.read_sql(query, engine)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniconda3/envs/ads507/lib/python3.12/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/miniconda3/envs/ads507/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File ~/miniconda3/envs/ads507/lib/python3.12/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...
